# %% [markdown]
# <a href="https://colab.research.google.com/github/Yalda-Ashrafi/K_Nearest_Neighbours/blob/main/K_Nearest_Neighbours.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('Social_Network_Ads.csv')

# %%
df.head()
# Out:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0
# 2   26            43000          0
# 3   27            57000          0
# 4   19            76000          0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   User ID          400 non-null    int64
#  1   Gender           400 non-null    object
#  2   Age              400 non-null    int64
#  3   EstimatedSalary  400 non-null    int64
#  4   Purchased        400 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 15.8+ KB

# %%
df['Purchased'].value_counts()
# Out:
# Purchased
# 0    257
# 1    143
# Name: count, dtype: int64

# %%
# The 'Gender' column does not exist in the DataFrame, skipping one-hot encoding for Gender.

# %%
x=df[['Age','EstimatedSalary']]
y=df['Purchased']

# %%
from sklearn.preprocessing import StandardScaler
scalr = StandardScaler()
scalr.fit(x)
# Out:
# StandardScaler()

# %%
scaled_features=scalr.transform(x)
scaled_features
# Out:
# array([[-1.78179743, -1.49004624],
#        [-0.25358736, -1.46068138],
#        [-1.11320552, -0.78528968],
#        [-1.01769239, -0.37418169],
#        [-1.78179743,  0.18375059],
#        [-1.01769239, -0.34481683],
#        [-1.01769239,  0.41866944],
#        [-0.54012675,  2.35674998],
#        [-1.20871865, -1.07893824],
#        [-0.25358736, -0.13926283],
#        [-1.11320552,  0.30121002],
#        [-1.11320552, -0.52100597],
#        [-1.6862843 ,  0.47739916],
#        [-0.54012675, -1.51941109],
#        [-1.87731056,  0.35993973],
#        [-0.82666613,  0.30121002],
#        [ 0.89257019, -1.3138571 ],
#        [ 0.70154394, -1.28449224],
#        [ 0.79705706, -1.22576253],
#        [ 0.98808332, -1.19639767],
#        [ 0.70154394, -1.40195167],
#        [ 0.89257019, -0.60910054],
#        [ 0.98808332, -0.84401939],
#        [ 0.70154394, -1.40195167],
#        [ 0.79705706, -1.37258681],
#        [ 0.89257019, -1.46068138],
#        [ 1.08359645, -1.22576253],
# ...

# %%
df_feat=pd.DataFrame(scaled_features,columns=x.columns)
df_feat.head()
# Out:
#         Age  EstimatedSalary
# 0 -1.781797        -1.490046
# 1 -0.253587        -1.460681
# 2 -1.113206        -0.785290
# 3 -1.017692        -0.374182
# 4 -1.781797         0.183751

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(scaled_features,y,test_size=0.2)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=1)

# %%
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=1)

# %%
pred=knn.predict(x_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix
confusion_matrix(y_test,pred)
# Out:
# array([[49,  1],
#        [ 6, 24]])

# %%
print(classification_report(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.98      0.93        50
#            1       0.96      0.80      0.87        30
#
#     accuracy                           0.91        80
#    macro avg       0.93      0.89      0.90        80
# weighted avg       0.92      0.91      0.91        80
